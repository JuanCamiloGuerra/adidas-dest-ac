# %% [markdown]
# # 02 · Visualización empresarial
#
# Cálculo reproducible de KPIs y lectura de los principales impulsores.
#
# **Reproducibilidad:** ejecutar desde la raíz del repositorio después del paso correspondiente de `scripts/run_all.py`.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve()
if ROOT.name == 'notebooks': ROOT = ROOT.parent
if str(ROOT) not in sys.path: sys.path.insert(0, str(ROOT))
print(f'Proyecto detectado: {ROOT.name}')
# Out:
# Proyecto detectado: adidas-dest-ac

# %%
import pandas as pd
from src.business_insights import calculate_kpis, generate_insights
orders = pd.read_parquet(ROOT/'data/processed/orders_enriched.parquet')
orders['order_date'] = pd.to_datetime(orders['order_date'])
kpis = calculate_kpis(orders)
kpis
# Out:
# {'total_revenue': 4174258.9200000004,
#  'units_sold': 45414.0,
#  'orders': 200,
#  'customers': 85,
#  'average_order_revenue': 20871.2946,
#  'average_unit_price': 91.9156850310477,
#  'leading_country': 'Colombia',
#  'leading_country_share': 0.2704864100763543,
#  'leading_channel': 'E-commerce B2B',
#  'leading_channel_share': 0.3781810137450697,
#  'leading_category': 'Footwear',
#  'leading_category_share': 0.47849293210589816,
#  'delivered_order_rate': 0.465,
#  'latest_month_change': 0.13550538652826205,
#  'formula_notes': {'total_revenue': 'Suma de unit_price × quantity para líneas válidas.',
#   'units_sold': 'Suma de quantity para líneas válidas.',
#   'orders': 'Conteo distinto de order_id con al menos una línea válida.',
#   'customers': 'Conteo distinto de user_id con al menos una línea válida.',
#   'average_order_revenue': 'Ingreso total dividido por pedidos distintos.',
#   'average_unit_price': 'Ingreso total dividido por unidades vendidas.',
#   'delivered_order_rate': 'Pedidos entregados divididos por pedidos totales, a nivel pedido.'}}

# %%
sales = orders[orders['valid_sales_flag']]
sales.groupby('country')['revenue'].sum().sort_values(ascending=False).to_frame('revenue')
# Out:
#               revenue
# country
# Colombia   1129080.31
# Perú        785493.85
# México      765138.41
# Argentina   763231.36
# Chile       731314.99

# %%
pd.DataFrame(generate_insights(orders))[['title','observation','action']]
# Out:
#                            title  \
# 0       Concentración geográfica
# 1  Canal que sostiene el negocio
# 2             Categoría tractora
# 3      Concentración de clientes
# 4        Cumplimiento de pedidos
# 5             Cierre del periodo
#
#                                          observation  \
# 0  Colombia genera 27.0% de los ingresos ($1,129,...
# 1  E-commerce B2B concentra 37.8% del revenue ($1...
# 2    Footwear aporta 47.8% del ingreso ($1,997,353).
# 3  Los 10 clientes con mayor facturación represen...
# 4  46.5% de los pedidos están entregados y 13.5% ...
# 5  El ingreso del último mes cambió +13.6% frente...
#
#                                               action
# 0  Proteger cuentas clave en Colombia y desarroll...
# 1  Analizar surtido y ticket de E-commerce B2B y ...
# 2  Priorizar disponibilidad de Footwear y diseñar...
# 3  Asignar planes de cuenta a los clientes princi...
# 4  Crear seguimiento semanal por estado, país y c...
# 5  Monitorear una serie histórica más larga y con...

# %% [markdown]
# ## Conclusión
#
# La narrativa se centra en escala, concentración y cumplimiento. El HTML final implementa los gráficos y filtros sin backend.
